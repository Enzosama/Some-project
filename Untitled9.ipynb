# %% [markdown]
# <a href="https://colab.research.google.com/github/Enzosama/Some-project/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def clean_sitemap(filename):
  """Đọc file sitemap.txt và trích xuất các link"""
  with open(filename, 'r') as file:
    content = file.read()
  links = re.findall(r'https?://(?:www\.)?[\w-]+(?:\.[a-z]{2,})+(?:[\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?', content)

  return links

def save_links_to_txt(links, filename):
  """Lưu danh sách các link vào file txt"""
  with open(filename, 'w') as file:
    for link in links:
      file.write(link + '\n')

# Đường dẫn đến file sitemap.txt
filename_sitemap = '/content/sample_data/sitemap.txt'

# Đường dẫn đến file txt để lưu kết quả
filename_output = '/content/sample_data/links.txt'
links = clean_sitemap(filename_sitemap)
save_links_to_txt(links, filename_output)
print(f"Đã lưu {len(links)} link vào file {filename_output}")
# Out:
# Đã lưu 28207 link vào file /content/sample_data/links.txt

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import zipfile
from google.colab import files

links_file_path = "/content/sample_data/links.txt"
image_dir = "images"

# Tạo thư mục images nếu chưa tồn tại
os.makedirs(image_dir, exist_ok=True)

with open(links_file_path, "r") as f:
    links = f.readlines()
for link in links:
    link = link.strip()
    print(f"Đang xử lý link: {link}")

    try:
        response = requests.get(link)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"  Lỗi tải trang: {e}")
        continue
    soup = BeautifulSoup(response.content, "html.parser")
    images = soup.find_all("img")
    for image in images:
        image_url = image.get("src")
        if not image_url:
            continue
        image_url = urljoin(link, image_url)
        try:
            image_data = requests.get(image_url).content
            image_name = image_url.split("/")[-1]
            image_path = os.path.join(image_dir, image_name)
            with open(image_path, "wb") as f:
                f.write(image_data)

            print(f"  Đã tải ảnh: {image_name}")

        except Exception as e:
            print(f"  Lỗi tải ảnh: {e}")
zip_path = "images.zip"
with zipfile.ZipFile(zip_path, 'w') as zipf:
    for root, _, files in os.walk(image_dir):
        for file in files:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), image_dir))
files.download(zip_path)
# Out:
# Streaming output truncated to the last 5000 lines.
#   Đã tải ảnh: cabochon-rings-ri1.png
#   Đã tải ảnh: cadence_ring.png
#   Đã tải ảnh: loader-1.gif
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: red.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: lifetime_warranty_new_cross_uk.jpg
#   Đã tải ảnh: red.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: red.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: red.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: white.jpg
#   Đã tải ảnh: yellow.jpg
#   Đã tải ảnh: white.jpg
# ...
